# %%
import pandas as pd

# %%
data=pd.read_csv('df_colombia.csv')

# %%
data
# Out:
#               AREA     PERIMETER  WCOLGEN02_  WCOLGEN021 DPTO NOMBRE_DPT MPIO  \
# 0     1.627019e+10  6.165239e+05        1078         999  091   AMAZONAS  460
# 1     1.928537e+10  8.355093e+05        1080        1000  091   AMAZONAS  669
# 2     1.318208e+10  7.218203e+05        1081         835  091   AMAZONAS  405
# 3     1.499952e+10  7.837434e+05        1082         998  091   AMAZONAS  407
# 4     8.929184e+09  6.299199e+05        1083         834  091   AMAZONAS  263
# ...            ...           ...         ...         ...  ...        ...  ...
# 1117  6.281993e+09  5.430899e+05        1079        1016  097     VAUPES  666
# 1118  9.552698e+09  4.103455e+05         396         839  099    VICHADA  001
# 1119  2.038062e+10  6.783370e+05         416         840  099    VICHADA  524
# 1120  4.335355e+09  3.220503e+05         559         840  099    VICHADA  624
# 1121  6.578661e+10  1.589733e+06         575        1009  099    VICHADA  773
#
#             NOMBRE_MPI        NOMBRE_CAB CLASEMUN  MPIOS    ZONA OF_REG  \
# 0        MIRITI-PARANA     MIRITI-PARANA       CD  91460  ZONA16  DABOG
# 1     PUERTO SANTANDER  PUERTO SANTANDER       CD  91669  ZONA16  DABOG
# 2          LA CHORRERA       LA CHORRERA       CD  91405  ZONA16  DABOG
# 3           LA PEDRERA        LA PEDRERA       CD  91407  ZONA16  DABOG
# 4           EL ENCANTO        EL ENCANTO       CD  91263  ZONA16  DABOG
# ...                ...               ...      ...    ...     ...    ...
# 1117           TARAIRA           TARAIRA       CM  97666  ZONA16  DABOG
# 1118    PUERTO CARRENO    PUERTO CARRENO       CM  99001  ZONA16  DABOG
# 1119      LA PRIMAVERA      LA PRIMAVERA       CM  99524  ZONA16  DABOG
# 1120     SANTA ROSALIA     SANTA ROSALIA       CM  99624  ZONA16  DABOG
# 1121          CUMARIBO          CUMARIBO       CM  99773  ZONA16  DABOG
#
#         REG_ZONAS     HECTARES cod_dane
# 0     DABOGZONA16  1627019.153   091460
# 1     DABOGZONA16  1928536.689   091669
# 2     DABOGZONA16  1318207.855   091405
# 3     DABOGZONA16  1499952.382   091407
# 4     DABOGZONA16   892918.382   091263
# ...           ...          ...      ...
# 1117  DABOGZONA16   628199.294   097666
# 1118  DABOGZONA16   955269.758   099001
# 1119  DABOGZONA16  2038062.144   099524
# 1120  DABOGZONA16   433535.470   099624
# 1121  DABOGZONA16  6578660.918   099773
#
# [1122 rows x 16 columns]

# %%
data['DPTO']=data['DPTO'].apply(lambda x: '{0:0>3}'.format(x))
data['MPIO']=data['MPIO'].apply(lambda x: '{0:0>3}'.format(x))
data['COD_DANE']=data['DPTO'].astype(str)+data['MPIO'].astype(str)

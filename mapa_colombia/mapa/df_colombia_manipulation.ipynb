# %%
import pandas as pd

# %%
data=pd.read_csv('df_colombia.csv')

# %%
[{'label': label, 'value': label} for label in data['NOMBRE_MPI'].unique()]
# Out:
# [{'label': 'MIRITI-PARANA', 'value': 'MIRITI-PARANA'},
#  {'label': 'PUERTO SANTANDER', 'value': 'PUERTO SANTANDER'},
#  {'label': 'LA CHORRERA', 'value': 'LA CHORRERA'},
#  {'label': 'LA PEDRERA', 'value': 'LA PEDRERA'},
#  {'label': 'EL ENCANTO', 'value': 'EL ENCANTO'},
#  {'label': 'TARAPACA', 'value': 'TARAPACA'},
#  {'label': 'LETICIA', 'value': 'LETICIA'},
#  {'label': 'PUERTO NARINO', 'value': 'PUERTO NARINO'},
#  {'label': 'LA VICTORIA', 'value': 'LA VICTORIA'},
#  {'label': 'PUERTO ARICA', 'value': 'PUERTO ARICA'},
#  {'label': 'PUERTO ALEGRIA', 'value': 'PUERTO ALEGRIA'},
#  {'label': 'ARBOLETES', 'value': 'ARBOLETES'},
#  {'label': 'SAN JUAN DE URABA', 'value': 'SAN JUAN DE URABA'},
#  {'label': 'NECOCLI', 'value': 'NECOCLI'},
#  {'label': 'SAN PEDRO DE URABA', 'value': 'SAN PEDRO DE URABA'},
#  {'label': 'TURBO', 'value': 'TURBO'},
#  {'label': 'NECHI', 'value': 'NECHI'},
#  {'label': 'EL BAGRE', 'value': 'EL BAGRE'},
#  {'label': 'APARTADO', 'value': 'APARTADO'},
# ...

# %%
data['DPTO']=data['DPTO'].apply(lambda x: '{0:0>3}'.format(x))
data['MPIO']=data['MPIO'].apply(lambda x: '{0:0>3}'.format(x))
data['COD_DANE']=data['DPTO'].astype(str)+data['MPIO'].astype(str)

# %%
import pandas as pd

income = pd.read_csv('Chile.csv', usecols=['income'])
list(income['income'])
# Out:
# [35000.0,
#  7500.0,
#  15000.0,
#  35000.0,
#  35000.0,
#  7500.0,
#  35000.0,
#  15000.0,
#  15000.0,
#  15000.0,
#  15000.0,
#  35000.0,
#  nan,
#  75000.0,
#  35000.0,
#  15000.0,
#  15000.0,
#  35000.0,
#  75000.0,
#  2500.0,
#  35000.0,
#  35000.0,
#  75000.0,
#  35000.0,
#  35000.0,
#  35000.0,
#  7500.0,
#  nan,
#  35000.0,
#  35000.0,
#  35000.0,
#  200000.0,
#  7500.0,
#  35000.0,
#  15000.0,
#  35000.0,
#  7500.0,
#  35000.0,
#  15000.0,
#  15000.0,
#  35000.0,
#  15000.0,
#  35000.0,
#  15000.0,
#  35000.0,
#  7500.0,
#  15000.0,
#  35000.0,
#  35000.0,
#  35000.0,
#  7500.0,
#  35000.0,
#  35000.0,
#  75000.0,
#  15000.0,
#  125000.0,
#  35000.0,
#  35000.0,
#  35000.0,
#  75000.0,
#  75000.0,
#  15000.0,
#  35000.0,
#  15000.0,
#  15000.0,
#  35000.0,
#  15000.0,
#  7500.0,
#  35000.0,
#  75000.0,
#  35000.0,
#  35000.0,
#  75000.0,
#  35000.0,
#  75000.0,
#  nan,
#  75000.0,
#  35000.0,
#  35000.0,
#  75000.0,
#  15000.0,
#  35000.0,
#  35000.0,
#  75000.0,
# ...
